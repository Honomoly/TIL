# %%
import numpy as np
a = np.zeros(7)
a

# %%
a[3]

# %%
list(range(1,9))

# %%
from pi_function import *
import matplotlib.pyplot as plt

# %%
N = 30
p_list = pi_function(N)
x_axis = list(range(1, N+1))
y_axis = []
for i in range(len(p_list)):
    if i == 0:
        y_axis = [0]
        continue
    p_i = p_list[i]
    p_1_1 = p_list[i-1]
    for j in range(p_i - p_i_1):
        y_axis.append(p_i_1)
p_1 = p_list[-1]
for j in range(30 - p_1):
    y_axis.append(p_1)
y_axis
# Out:
# [0,
#  2,
#  3,
#  3,
#  5,
#  5,
#  7,
#  7,
#  7,
#  7,
#  11,
#  11,
#  13,
#  13,
#  13,
#  13,
#  17,
#  17,
#  19,
#  19,
#  19,
#  19,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23]
